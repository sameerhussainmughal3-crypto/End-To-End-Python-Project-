# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in c:\users\hp\anaconda3\anaconda\lib\site-packages (1.8.3)
# Requirement already satisfied: black>=24.10.0 in c:\users\hp\anaconda3\anaconda\lib\site-packages (from kaggle) (24.10.0)
# Requirement already satisfied: bleach in c:\users\hp\anaconda3\anaconda\lib\site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in c:\users\hp\anaconda3\anaconda\lib\site-packages (from kaggle) (0.1.14)
# Requirement already satisfied: mypy>=1.15.0 in c:\users\hp\anaconda3\anaconda\lib\site-packages (from kaggle) (1.19.1)
# Requirement already satisfied: packaging in c:\users\hp\appdata\roaming\python\python313\site-packages (from kaggle) (25.0)
# Requirement already satisfied: protobuf in c:\users\hp\anaconda3\anaconda\lib\site-packages (from kaggle) (5.29.3)
# Requirement already satisfied: python-dateutil in c:\users\hp\appdata\roaming\python\python313\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in c:\users\hp\anaconda3\anaconda\lib\site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: requests in c:\users\hp\anaconda3\anaconda\lib\site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: six>=1.10 in c:\users\hp\appdata\roaming\python\python313\site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: tqdm in c:\users\hp\anaconda3\anaconda\lib\site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: types-requests in c:\users\hp\anaconda3\anaconda\lib\site-packages (from kaggle) (2.32.4.20250913)
# Requirement already satisfied: types-tqdm in c:\users\hp\anaconda3\anaconda\lib\site-packages (from kaggle) (4.67.0.20250809)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\hp\anaconda3\anaconda\lib\site-packages (from kaggle) (2.5.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\hp\anaconda3\anaconda\lib\site-packages (from black>=24.10.0->kaggle) (8.1.8)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\hp\anaconda3\anaconda\lib\site-packages (from black>=24.10.0->kaggle) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\hp\anaconda3\anaconda\lib\site-packages (from black>=24.10.0->kaggle) (0.10.3)
# Requirement already satisfied: platformdirs>=2 in c:\users\hp\appdata\roaming\python\python313\site-packages (from black>=24.10.0->kaggle) (4.3.8)
# Requirement already satisfied: colorama in c:\users\hp\appdata\roaming\python\python313\site-packages (from click>=8.0.0->black>=24.10.0->kaggle) (0.4.6)
# Requirement already satisfied: typing_extensions>=4.6.0 in c:\users\hp\anaconda3\anaconda\lib\site-packages (from mypy>=1.15.0->kaggle) (4.15.0)
# Requirement already satisfied: librt>=0.6.2 in c:\users\hp\anaconda3\anaconda\lib\site-packages (from mypy>=1.15.0->kaggle) (0.7.5)
# Requirement already satisfied: webencodings in c:\users\hp\anaconda3\anaconda\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\hp\anaconda3\anaconda\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\anaconda\lib\site-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\anaconda\lib\site-packages (from requests->kaggle) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\anaconda\lib\site-packages (from requests->kaggle) (2025.11.12)

# %%
import kaggle

# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# Downloading orders.csv.zip to D:\kaggle
#   0%|          | 0.00/200k [00:00<?, ?B/s]
# 100%|##########| 200k/200k [00:00<00:00, 342kB/s]
# 100%|##########| 200k/200k [00:00<00:00, 341kB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('orders.csv.zip') 
zip_ref.extractall() # extract file to dir
zip_ref.close() # close file
